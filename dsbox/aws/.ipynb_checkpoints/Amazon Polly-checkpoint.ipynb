# %%
import os
import IPython.display as ipd

# %%
text = open('revel.txt','r').read().replace('\n',' ')

# %%
text
# Out:
# 'Revel is a full-service digital consultancy that partners with organizations to lead go-to-market transformation by building seamless, simple, connected experiences. We are problem solvers, designers and builders united around a core set of values and a commitment to solving complex challenges swiftly, efficiently and elegantly.'

# %%
command = 'aws polly synthesize-speech --output-format mp3 --voice-id Joanna --text "'+\
text+'" ./Audio/revel_joanna_normal.mp3'

# %%
os.system(command)
# Out:
# 0

# %%
ipd.Audio('Audio/revel_joanna_normal.mp3')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
command
# Out:
# 'aws polly synthesize-speech --output-format mp3 --voice-id Joanna --text "Revel is a full-service digital consultancy that partners with organizations to lead go-to-market transformation by building seamless, simple, connected experiences. We are problem solvers, designers and builders united around a core set of values and a commitment to solving complex challenges swiftly, efficiently and elegantly." ./Audio/revel_joanna_normal.mp3'
